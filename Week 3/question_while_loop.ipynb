# %% [markdown]
# ***Problem 1*** Find the factorial of the given number
#
#
#    ### Creating this Table Without Coding
#  **Test Cases**
#  | **Sr. No.** | **Input** | **Expected Output** |
# |:------------:|:---------:|:------------------:|
#  | 1 | 5 | 120 |
#  | 2 | 2 | 2 |
#  | 3 | 0 | 1 |
#  | 4 | -7 | Not defined |
#
# <br>
#
# ### Creating this Table using HTML
#
# <table style="border-collapse: collapse; width: 60%; text-align: center;">
#   <tr style="background-color: #d87b2e; color: Black;">
#     <th colspan="3">Test Cases</th>
#   </tr>
#   <tr style="background-color: #0f0d0cff;">
#     <th>Sr. No.</th>
#     <th>Input</th>
#     <th>Expected Output</th>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>5</td>
#     <td>120</td>
#   </tr>
#   <tr style="background-color: #b97144ff;">
#     <td>2</td>
#     <td>2</td>
#     <td>2</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>0</td>
#     <td>1</td>
#   </tr>
#   <tr style="background-color: #2b1a0fff;">
#     <td>4</td>
#     <td>-7</td>
#     <td>Not defined</td>
#   </tr>
# </table>

# %%
# robust input loop to avoid ValueError on empty/invalid input
while True:
    s = input("Enter A number: ").strip()
    if s == "":
        print("No input provided. Please enter an integer.")
        continue
    try:
        num = int(s)
        break
    except ValueError:
        print("Invalid input. Please enter a valid integer.")

fact = 1
if num < 0:
    print("Not Defined for negative numbers")
else:
    # compute factorial (0! = 1)
    while num > 0:
        fact *= num
        num -= 1
    print("Factorial is:", fact)

# %% [markdown]
# ***Problem 2:*** Find the number of digit in the given number
#
# ### Creating this Table using HTML
#
# <table style="border-collapse: collapse; width: 60%; text-align: center;">
#   <tr style="background-color: #f4f2f0ff; color: Black;">
#     <th colspan="3">Test Cases</th>
#   </tr>
#   <tr style="background-color: #0f0d0cff;">
#     <th>Sr. No.</th>
#     <th>Input</th>
#     <th>Expected Output</th>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>1234</td>
#     <td>4</td>
#   </tr>
#   <tr style="background-color: #b97144ff;">
#     <td>2</td>
#     <td>1234567890</td>
#     <td>10</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>8</td>
#     <td>1</td>
#   </tr>
#   <tr style="background-color: #2b1a0fff;">
#     <td>4</td>
#     <td>0</td>
#     <td>1</td>
#   </tr>
#   <tr style="background-color: #713913ff;">
#     <td>5</td>
#     <td>-4</td>
#     <td>1</td>
#   </tr>
# </table>

# %%
# robust input loop to avoid ValueError on empty/invalid input
while True:
    s = input("Enter A number: ").strip()
    if s == "":
        print("No input provided. Please enter an integer.")
        continue
    try:
        num = int(s)
        break
    except ValueError:
        print("Invalid input. Please enter a valid integer.")

# count digits in the absolute value (0 has 1 digit)
num = abs(num)
if num == 0:
    count = 1
else:
    count = 0
    while num > 0:
        count += 1
        num //= 10
print("Number of digits are:", count)
# Out:
# Number of digits are: 3

# %% [markdown]
# ***Problem 3:*** Reverse the digits inthe Given Number
#
# ### Creating this Table using HTML
#
# <table style="border-collapse: collapse; width: 60%; text-align: center;">
#   <tr style="background-color: #d87b2e; color: Black;">
#     <th colspan="3">Test Cases</th>
#   </tr>
#   <tr style="background-color: #0f0d0cff;">
#     <th>Sr. No.</th>
#     <th>Input</th>
#     <th>Expected Output</th>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>1234</td>
#     <td>4321</td>
#   </tr>
#   <tr style="background-color: #b97144ff;">
#     <td>2</td>
#     <td>123456789</td>
#     <td>987654321</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>8</td>
#     <td>8</td>
#   </tr>
#   <tr style="background-color: #2b1a0fff;">
#     <td>4</td>
#     <td>0</td>
#     <td>0</td>
#   </tr>
#   </tr>
#   <tr style="background-color: #703b18ff;">
#     <td>5</td>
#     <td>-1234</td>
#     <td>-4321</td>
#   </tr>
# </table>

# %%
num = int(input("Enter A Number: "))
absNum = abs(num)
rev = absNum % 10 
absNum = absNum// 10 
while(absNum>0):
        r = absNum % 10
        absNum = absNum//10
        rev = rev *10 +r
if(num>=0):
    print(rev)
else:
    print(rev - 2 *rev)
# Out:
# 95

# %% [markdown]
# ***Problem 4***: Find whether the entered number is palindrome or not
#
# ### Creating this Table using HTML
#
# <table style="border-collapse: collapse; width: 60%; text-align: center;">
#   <tr style="background-color: #d87b2e; color: Black;">
#     <th colspan="3">Test Cases</th>
#   </tr>
#   <tr style="background-color: #0f0d0cff;">
#     <th>Sr. No.</th>
#     <th>Input</th>
#     <th>Expected Output</th>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>12321</td>
#     <td>Palindrome</td>
#   </tr>
#   <tr style="background-color: #b97144ff;">
#     <td>2</td>
#     <td>1221</td>
#     <td>Palindrome</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>1234</td>
#     <td>Not a Palindrome</td>
#   </tr>
#   <tr style="background-color: #2b1a0fff;">
#     <td>4</td>
#     <td>123421</td>
#     <td>Not a Palindrome</td>
#   </tr>
#   <tr style="background-color: #703b18ff;">
#     <td>5</td>
#     <td>9</td>
#     <td>Palindrome</td>
#   </tr>
#   <tr style="background-color: #26211dff;">
#     <td>6</td>
#     <td>-1221</td>
#     <td>Palindrome</td>
#   </tr>
# </table>

# %%
num = int(input("Enter A Number: "))
absNum = abs(num)
rev = absNum % 10 
absNum = absNum// 10 
while(absNum>0):
    r = absNum % 10
    absNum = absNum//10
    rev = rev *10 +r
if(num <0):
    rev = rev - 2 * rev    
if(num==rev):
    print("Palindrome")
else:
    print("Not a Palindrome")
# Out:
# Palindrome
